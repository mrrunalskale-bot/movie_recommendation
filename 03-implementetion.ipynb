# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('final_data.csv')

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
dtm = cv.fit_transform(df['tags'])
dtm_df = pd.DataFrame(data = dtm.toarray() , columns = cv.get_feature_names_out())

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarities = cosine_similarity(dtm_df)

# %%
similarities[0]
df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                    tags
# 0     thomas-nittmann,david-stinnett,mayes-c.-rubeo,...
# 1     lee-arenberg,david-schofield,ship,traitor,barb...
# 2     rachid-aadassi,oleg-mirochnikov,karl-farrer,da...
# 3     lex-daniel,ian-bohen,joe-guzman,maxx-wai-in-le...
# 4     paula-price,andrew-m.-ward,gary-machin,mayes-c...
# ...                                                 ...
# 4798  came,legs,mistake,paper-knife,arms,thriller,tr...
# 4799  ,aaron-lubin,arrival,newlywed,respective,kerry...
# 4800  ,date,office,team,system,package,post,take,joe...
# 4801  ,mess,career,clever,yorker,bill-paxton,send,en...
# 4802  dream,,date,broke,samuel-l.-jackson,herzlinger...
#
# [4803 rows x 3 columns]

# %%
def get_movie_index(name):
    for i in df.index:
        if name == df.loc[i, 'title']:
            return i
    else:
        return -1

def get_movie_name(i):
    if i > len(df):
        return ""
    else:
        return df.loc[i, 'title']

# %%
name = input('Enter movie name')
index = get_movie_index(name)
if index == -1:
    print('sorry movie not found')
else:
    similarity_index = similarities[index]
    similarity_index = list(enumerate(similarity_index))
    similarity_index = sorted(similarity_index, key = lambda x:x[1], reverse = True)
    print('predict next 5 movies')
    for i in range(1,6):
        print(str(i) + ". " + get_movie_name(similarity_index[i][0]))
# Out:
# Enter movie name Harry Potter and the Prisoner of Azkaban
# predict next 5 movies
# 1. Harry Potter and the Chamber of Secrets
# 2. Harry Potter and the Philosopher's Stone
# 3. Harry Potter and the Goblet of Fire
# 4. Harry Potter and the Half-Blood Prince
# 5. Harry Potter and the Order of the Phoenix

# %%
import pickle
pickle.dump(similarities, open('similarities.pkl', 'wb'))
