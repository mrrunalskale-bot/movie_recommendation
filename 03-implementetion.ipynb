# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('final_data.csv')

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
dtm = cv.fit_transform(df['tags'])
dtm_df = pd.DataFrame(data = dtm.toarray() , columns = cv.get_feature_names_out())

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarities = cosine_similarity(dtm_df)

# %%
similarities[0]
df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                    tags
# 0     brad-alexander,iain-hutton,tear,pandora,mali-f...
# 1     john-dexter,afterlife,stephen-e.-rivkin,hans-z...
# 2     john-t.-cucci,matteo-taranto,zave-jackson,dani...
# 3     daniel-sunjata,jay-wejebe,villainess,jenne-lee...
# 4     eamonn-butler,kacie-seamons,lori-korngiebel,19...
# ...                                                 ...
# 4798  azul,want,lord,try,jaime-de-hoyos,play,town,ca...
# 4799  ,marsha-dietlein,daniella-pineda,edward-burns,...
# 4800  ,letter,future,world,front-street-pictures,car...
# 4801  ,clever,shanghai,immediately,write,send,legal,...
# 4802  ,eric-roberts,try,barrymore,date,herzlinger,dr...
#
# [4803 rows x 3 columns]

# %%
def get_movie_index(name):
    for i in df.index:
        if name == df.loc[i, 'title']:
            return i
    else:
        return -1

def get_movie_name(i):
    if i > len(df):
        return ""
    else:
        return df.loc[i, 'title']

# %%
name = input('Enter movie name')
index = get_movie_index(name)
if index == -1:
    print('sorry movie not found')
else:
    similarity_index = similarities[index]
    similarity_index = list(enumerate(similarity_index))
    similarity_index = sorted(similarity_index, key = lambda x:x[1], reverse = True)
    print('predict next 5 movies')
    for i in range(1,6):
        print(str(i) + ". " + get_movie_name(similarity_index[i][0]))
# Out:
# Enter movie name Avatar
# predict next 5 movies
# 1. Jurassic World
# 2. 15 Minutes
# 3. The Dark Knight Rises
# 4. A.I. Artificial Intelligence
# 5. Suicide Squad

# %%
import pickle
pickle.dump(similarities, open('similarities.pkl', 'wb'))
